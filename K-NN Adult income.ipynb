# %% [markdown]
# <a href="https://colab.research.google.com/github/shahorier918/Machine-Leaning-/blob/main/K-NN%20Adult%20income.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **K-Nearest Neighbors (KNN)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


df = pd.read_csv('/content/adult.csv', index_col=0)


df.head()
# Out:
#      workclass  fnlwgt     education  educational-num      marital-status  \
# age
# 25     Private  226802          11th                7       Never-married
# 38     Private   89814       HS-grad                9  Married-civ-spouse
# 28   Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 44     Private  160323  Some-college               10  Married-civ-spouse
# 18           ?  103497  Some-college               10       Never-married
#
#             occupation relationship   race  gender  capital-gain  \
# age
# 25   Machine-op-inspct    Own-child  Black    Male             0
# 38     Farming-fishing      Husband  White    Male             0
# 28     Protective-serv      Husband  White    Male             0
# 44   Machine-op-inspct      Husband  Black    Male          7688
# 18                   ?    Own-child  White  Female             0
#
#      capital-loss  hours-per-week native-country income
# age
# ...

# %%
# prompt: Using dataframe df: race

# Group data by race and count the number of people in each race
race_counts = df.groupby('race')['race'].count()

# Display the counts
race_counts
# Out:
# race
# Amer-Indian-Eskimo      470
# Asian-Pac-Islander     1519
# Black                  4685
# Other                   406
# White                 41762
# Name: race, dtype: int64

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-7-1af3962d8ca7> in <cell line: 2>()
#       1 from google.colab import sheets
# ----> 2 sheet = sheets.InteractiveSheet(df=df)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py in __init__(self, title, url, sheet_id, df, worksheet_id, worksheet_name, credentials, include_column_headers, display)
#     110       url = f'https://docs.google.com/spreadsheets/d/{sheet_id}'
#     111     self._credentials = credentials
# --> 112     self._ensure_gspread_client()
#     113
#     114     self.sheet = self._load_or_create_sheet(url, title)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py in _ensure_gspread_client(self)
#     166     global _gspread_client
#     167     if _gspread_client is None:
# --> 168       creds = InteractiveSheet.generate_creds(self._credentials)
# ...
